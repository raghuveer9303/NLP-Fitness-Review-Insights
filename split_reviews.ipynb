# %%
import os
import json
import psycopg2
from psycopg2.extras import register_default_json
from langdetect import detect, LangDetectException
import google.generativeai as genai
from google.generativeai import types

# %%
DB_CONFIG = {
    'user': 'admin',
    'host': 'raghuserver',
    'database': 'SII',
    'password': 'raghu@123',
    'port': 5432
}

# %%
def connect_db(config):
    try:
        conn = psycopg2.connect(**config)
        register_default_json(conn)
        return conn
    except Exception as e:
        print(f"Error connecting to database: {e}")
        return None

# %%
import re, json

def extract_json(text):
    """
    Extract the first valid JSON object from a string.
    """
    # Remove any ``` or ```json fences
    text = re.sub(r'```(?:json)?\n?', '', text)
    
    # Find the first {...} span
    m = re.search(r'\{.*\}', text, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found")
    
    json_str = m.group(0)
    
    # Validate
    try:
        json.loads(json_str)
    except json.JSONDecodeError as e:
        raise ValueError(f"Invalid JSON: {e}")
    
    return json_str


def punctuate_and_split_model(text, model):
    """
    text: string containing a single review
    Returns: list of sentences
    """
    prompt = f"""
        You will receive a text. Your task is to:
        1. Insert appropriate punctuation without changing any words.
        2. Split the result into natural sentences.
        3. Return a JSON array of the punctuated sentences.

        RULES:
        • **Output must be valid JSON only**—no extra text, no explanations.
        • If the text cannot be split, return it as a single-element array.
        • Do not reorder, remove, or add any words.

        Input:
        {text}

        Output:
    """
    
    # Make up to 3 attempts to get valid JSON
    for _ in range(3):
        try:
            response = model.generate_content(prompt)
            json_str = extract_json(response.text)
            sentences = json.loads(json_str)
            if isinstance(sentences, list):
                return sentences
        except (ValueError, json.JSONDecodeError) as e:
            continue
        
    raise ValueError("Failed to get valid JSON after 3 attempts")

# %%
from sentencex import segment

def punctuate_and_split_single(text, model):
    """
    text: string containing a single review
    Returns: list of sentences
    """
    try:
        # Use sentencex to split the text into sentences
        sentences = list(segment('en', text))
        return sentences
    except Exception as e:
        print(f"Error splitting sentences: {e}")
        return [text]

# %%
from dotenv import load_dotenv
load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY", "your-gemini-api-key-here")

def setup_gemini_api():
    genai.configure(api_key=GEMINI_API_KEY)
    model = genai.GenerativeModel('gemini-2.0-flash-lite')
    return model

# %%
from langdetect import detect, LangDetectException

def detect_language(text):
    try:
        return detect(text)
    except LangDetectException as e:
        print(f"Error detecting language: {e}")
        return 'unknown'

# %%
def has_punctuation(text):
    """Check if text contains sentence-ending punctuation."""
    return any(char in text for char in '.!?')

def process_reviews():
    '''
    Connects to the database, fetches unprocessed reviews, splits them into sentences, and stores the results.
    Can be imported and called from other scripts.
    '''
    print("Connecting to database...")
    conn = connect_db(DB_CONFIG)
    if not conn:
        print("Failed to connect to database")
        return
    print("Setting up cursor...")
    cur = conn.cursor()
    processed = 0
    while True:
        cur.execute("""
            SELECT id, body
            FROM combined_reviews
            WHERE processed = FALSE
            AND body IS NOT NULL
            AND length(trim(body)) > 0
            ORDER BY id
            LIMIT 1
        """)
        row = cur.fetchone()
        if not row:
            print(f'No more reviews to process. Total processed: {processed}')
            break
        review_id, body = row
        print(f'\nProcessing review {review_id}: {body[:50]}...')
        lang = detect_language(body)
        if lang != 'en':
            print(f'Skipping non-English review (detected: {lang})')
            cur.execute("""
                UPDATE combined_reviews
                SET processed = TRUE
                WHERE id = %s
            """, (review_id,))
            continue
        try:
            sentences = punctuate_and_split_single(body, None)
            print(f'Split into {len(sentences)} sentences')
            for idx, sent in enumerate(sentences, start=1):
                cur.execute("""
                    INSERT INTO review_sentences (review_id, sentence_num, sentence)
                    VALUES (%s, %s, %s)
                """, (review_id, idx, sent))
            cur.execute("""
                UPDATE combined_reviews
                SET processed = TRUE
                WHERE id = %s
            """, (review_id,))
            conn.commit()
            processed += 1
            print(f'Successfully processed review {review_id}')
        except Exception as e:
            print(f'Error processing review {review_id}: {e}')
            conn.rollback()
    print(f'\nFinished processing. Total reviews processed: {processed}')
    cur.close()
    conn.close()
# Out:
# Connecting to database...
# Setting up cursor...
#
# Processing review 59945: Happy new owner,After a couple winters using the K...
# Split into 6 sentences
# Successfully processed review 59945
#
# Processing review 59946: I loved it,I loved it...
# Split into 1 sentences
# Successfully processed review 59946
#
# Processing review 59947: All season bike,Good quality build and easy to use...
# Split into 3 sentences
# Successfully processed review 59947
#
# Processing review 59948: Wahoo Kickr Bike,Wahoo Kickr Bike...
# Skipping non-English review (detected: so)
#
# Processing review 59949: Great bike! Very smooth riding.,Great bike! Very s...
# Split into 5 sentences
# Successfully processed review 59949
#
# Processing review 59950: Pricey but great quality,Excellent bit of kit. Pre...
# Split into 2 sentences
# Successfully processed review 59950
#
# Processing review 59951: A very good bike,I’ve been using the kickr bike fo...
# Split into 4 sentences
# Successfully processed review 59951
#
# Processing review 59952: Indoor training at it's best,Couldn't be happier w...
# Split into 2 sentences
# Successfully processed review 59952
#
# Processing review 59953: Perfect trainer for getting the,Perfect trainer fo...
# Split into 1 sentences
# Successfully processed review 59953
#
# Processing review 59954: Works great.. love it!,Works great.. love it!...
# Split into 4 sentences
# Successfully processed review 59954
#
# Processing review 59955: Kickr Bike,The bike works great, very smooth and s...
# Split into 7 sentences
# Successfully processed review 59955
#
# Processing review 59956: Wahoo Bike is the BOMB!,I ordered a refurbished Wa...
# Split into 5 sentences
# Successfully processed review 59956
#
# Processing review 59957: Fantastic product. Love how it,Fantastic product. ...
# Split into 3 sentences
# Successfully processed review 59957
#
# Processing review 59958: Great product!,Great product!...
# Split into 2 sentences
# Successfully processed review 59958
#
# Processing review 59959: Terrific !!,More realistic than the other stationa...
# Split into 4 sentences
# Successfully processed review 59959
#
# Processing review 59960: Easy to set up and,Easy to set up and use. Good de...
# Split into 3 sentences
# Successfully processed review 59960
#
# Processing review 59961: Changed cycling for ME! AMAZING!,Love this bike an...
# Split into 7 sentences
# Successfully processed review 59961
#
# Processing review 59962: Essential bit of kit,I purchased the bike as I wan...
# Split into 8 sentences
# Successfully processed review 59962
#
# Processing review 59963: Phenomenal training bike,I use TrainerRoad and the...
# Split into 3 sentences
# Successfully processed review 59963
#
# Processing review 59964: Amazing Upgrade,I upgraded from a Slocum Computrai...
# Split into 3 sentences
# Successfully processed review 59964
#
# Processing review 59965: Kickr Bike,Very good bike but some problems with s...
# Split into 2 sentences
# Successfully processed review 59965
#
# Processing review 59966: Great tool! Tech at your,Great tool! Tech at your ...
# Split into 3 sentences
# Successfully processed review 59966
#
# Processing review 59967: Great trainer,Easy to assemble and loads of fun co...
# Split into 1 sentences
# Successfully processed review 59967
#
# Processing review 59968: Great piece of kit,Having had the Kickr Bike for a...
# Split into 13 sentences
# Successfully processed review 59968
#
# Processing review 59969: Great bike, poor service,Great piece of kit, prett...
# Split into 7 sentences
# Successfully processed review 59969
#
# Processing review 59970: Good bike, fun to use,A really good bike. Took a l...
# Split into 4 sentences
# Successfully processed review 59970
#
# Processing review 59971: Great experience,Great alternative to getting out ...
# Split into 9 sentences
# Successfully processed review 59971
#
# Processing review 59972: Fantastic Product,Fantastic bit of kit. Takes indo...
# Split into 3 sentences
# Successfully processed review 59972
#
# Processing review 59973: Awesome Bike,Easy to set up and use. Brings back t...
# Split into 4 sentences
# Successfully processed review 59973
#
# Processing review 59974: Worth the wait,The setup was easy and connected qu...
# Split into 4 sentences
# Successfully processed review 59974
#
# Processing review 59975: Really well designed!,Build quality is great. Very...
# Split into 6 sentences
# Successfully processed review 59975
#
# Processing review 59976: Really like it,My wife and I use our Kickr Bike 5 ...
# Split into 2 sentences
# Successfully processed review 59976
#
# Processing review 59977: TOP,TOP...
# Skipping non-English review (detected: vi)
#
# Processing review 59978: Kickr Bike,Great service from Wahoo. Easy to set u...
# Split into 3 sentences
# Successfully processed review 59978
#
# Processing review 59979: fantastic!,fantastic!...
# Skipping non-English review (detected: ca)
#
# Processing review 59980: Second to none,Perfect hardware to get you on a Pr...
# Split into 1 sentences
# Successfully processed review 59980
#
# Processing review 59981: Great motivator,Had this for December and the setu...
# Split into 4 sentences
# Successfully processed review 59981
#
# Processing review 59982: Easy to love this bike.,Easy to love this bike.
#
# ...
# Split into 13 sentences
# Successfully processed review 59982
#
# Processing review 59983: Kickr Bike,I was fortunate to get one this year. G...
# Split into 5 sentences
# Successfully processed review 59983
#
# Processing review 59984: Great,Great...
# Split into 1 sentences
# Successfully processed review 59984
#
# Processing review 59985: Kickr Bike,At first I was hesitant to purchase due...
# Split into 3 sentences
# Successfully processed review 59985
#
# Processing review 59986: the app,I wish I could store my wife’s setup on th...
# Split into 1 sentences
# Successfully processed review 59986
#
# Processing review 59987: GREAT BIKE!!!,Ich habe mir das WAHOO KICKR BIKE ge...
# Skipping non-English review (detected: de)
#
# Processing review 59988: pair it with Rouvy AR for real feel,I have put 75 ...
# Split into 2 sentences
# Successfully processed review 59988
#
# Processing review 59989: Enjoying my new Kickr Bike,I received my bike with...
# Split into 23 sentences
# Successfully processed review 59989
#
# Processing review 59990: Climb function needs help but awesome anyway,Amazi...
# Split into 2 sentences
# Successfully processed review 59990
#
# Processing review 59991: Wahoo Bike 2 weeks in,It's sooooo good! Not totall...
# Split into 3 sentences
# Successfully processed review 59991
#
# Processing review 59992: Just amazing!!!,Wahoo kickr+Sufferfest+65" TV = co...
# Split into 2 sentences
# Successfully processed review 59992
#
# Processing review 59993: Wahoo Kickr Bike,Really fabulous build, great inst...
# Split into 2 sentences
# Successfully processed review 59993
#
# Processing review 59994: Kickr Bike,This is how all turbos should be -as cl...
# Split into 4 sentences
# Successfully processed review 59994
#
# Processing review 59995: A trainer you'll actually want to use,It doesn't m...
# Split into 4 sentences
# Successfully processed review 59995
#
# Processing review 59996: Worth the price.,I love this bike. I have had a sm...
# Split into 9 sentences
# Successfully processed review 59996
#
# Processing review 59997: Surviving CV crisis with the Kickr Bike / Zwift,Lo...
# Split into 4 sentences
# Successfully processed review 59997
#
# Processing review 59998: Happy with purchase so far,Ordered the bike from t...
# Split into 10 sentences
# Successfully processed review 59998
#
# Processing review 59999: A Step Up from the Kickr/Climb,The bike was delive...
# Split into 20 sentences
# Successfully processed review 59999
#
# Processing review 60000: Excellent except for the handlebars tape.,Wow! Wha...
# Split into 9 sentences
# Successfully processed review 60000
#
# Processing review 60001: Easy Rider,So far I'm stunned at how quiet the bik...
# Split into 4 sentences
# Successfully processed review 60001
#
# Processing review 60002: The Game Changer,What a piece of kit! Absolutely s...
# Split into 5 sentences
# Successfully processed review 60002
#
# Processing review 60003: Fanstastic!,Fantastic! Great bike. Very easy to fi...
# Split into 7 sentences
# Successfully processed review 60003
#
# Processing review 60004: HIGHLY recommend the KICKR Bike,I upgraded to the ...
# Split into 6 sentences
# Successfully processed review 60004
#
# Processing review 60005: Exceptional, but with room for improvement.,I have...
# Split into 24 sentences
# Successfully processed review 60005
#
# Processing review 60006: Great VR experience and ROI.,Excellent product. Se...
# Split into 8 sentences
# Successfully processed review 60006
#
# Processing review 60007: Next Level Indoor Cycling ...,We've had the KICKR ...
# Split into 6 sentences
# Successfully processed review 60007
#
# Processing review 60008: Incredible technology!,I'm a serious cyclist with ...
# Split into 9 sentences
# Successfully processed review 60008
#
# Processing review 60009: Amazing,Unbelievably real ride experience. Customi...
# Split into 3 sentences
# Successfully processed review 60009
#
# Processing review 60010: KICKR Bike - fantastic!,I have had my KICKR bike f...
# Split into 35 sentences
# Successfully processed review 60010
#
# Processing review 60011: AMAZING,Before I purchased the Wahoo bike I checke...
# Split into 7 sentences
# Successfully processed review 60011
#
# Processing review 60012: Amazing and ready to ride!,I love the new Kickr bi...
# Split into 10 sentences
# Successfully processed review 60012
#
# Processing review 60013: Overall good. Having issues with,Overall good. Hav...
# Split into 3 sentences
# Successfully processed review 60013
#
# Processing review 60014: Took a while to figure,Took a while to figure out ...
# Split into 1 sentences
# Successfully processed review 60014
#
# Processing review 60015: Great (If it works!),It's a great step up from a D...
# Split into 4 sentences
# Successfully processed review 60015
#
# Processing review 60016: Good bike, lots of adjustability,Overall I like th...
# Split into 24 sentences
# Successfully processed review 60016
#
# Processing review 60017: Very smooth operation. Feels just,Very smooth oper...
# Split into 7 sentences
# Successfully processed review 60017
#
# Processing review 60018: Love the climb features and,Love the climb feature...
# Split into 5 sentences
# Successfully processed review 60018
#
# Processing review 60019: Amazing - Almost perfect!,Super quiet, fully adjus...
# Split into 11 sentences
# Successfully processed review 60019
#
# Processing review 60020: Good purchase,Overall I am happy with the purchase...
# Split into 5 sentences
# Successfully processed review 60020
#
# Processing review 60021: Fantastic bike at a very affordable price,Use the ...
# Split into 2 sentences
# Successfully processed review 60021
#
# Processing review 60022: Overall I'm happy,Overall I'm very happy with the ...
# Split into 7 sentences
# Successfully processed review 60022
#
# Processing review 60023: Satisfied overall but shifting is rough,I moved to...
# Split into 7 sentences
# Successfully processed review 60023
#
# Processing review 60024: ….,…....
# Error detecting language: No features in text.
# Skipping non-English review (detected: unknown)
#
# Processing review 60025: Great Product with minor defects.,Product is great...
# Split into 7 sentences
# Successfully processed review 60025
#
# Processing review 60026: Be careful when tightening the base bolts,Great bi...
# Split into 6 sentences
# Successfully processed review 60026
#
# Processing review 60027: Kicker bike shift,Very disappointed with this bike...
# Split into 1 sentences
# Successfully processed review 60027
#
# Processing review 60028: Bummed to learn it still,Bummed to learn it still ...
# Split into 2 sentences
# Successfully processed review 60028
#
# Processing review 60029: contento ma non contentissimo,il prodotto è arriva...
# Skipping non-English review (detected: it)
#
# Processing review 60030: Best workout pairing,Best workout pairing...
# Split into 1 sentences
# Successfully processed review 60030
#
# Processing review 60031: Wahoo kickr bike,It came well packed and was extre...
# Split into 6 sentences
# Successfully processed review 60031
#
# Processing review 60032: Really enjoying it. Still getting,Really enjoying ...
# Split into 3 sentences
# Successfully processed review 60032
#
# Processing review 60033: Great ride, easy to fit, some components need upgr...
# Split into 11 sentences
# Successfully processed review 60033
#
# Processing review 60034: The bike is very nice.,The bike is very nice. A we...
# Split into 4 sentences
# Successfully processed review 60034
#
# Processing review 60035: Everything was fine until we,Everything was fine u...
# Split into 8 sentences
# Successfully processed review 60035
#
# Processing review 60036: Kickr bike refurbished,I have had the Kickr bike f...
# Split into 3 sentences
# Successfully processed review 60036
#
# Processing review 60037: Yes,Since I am a coach I do not need the screen ju...
# Split into 1 sentences
# Successfully processed review 60037
#
# Processing review 60038: Great, but,Overall, I love it. After first ride I ...
# Split into 8 sentences
# Successfully processed review 60038
#
# Processing review 60039: Up Shifting four and five,Up Shifting four and fiv...
# Split into 1 sentences
# Successfully processed review 60039
#
# Processing review 60040: Overall great, but not silent,Overall a great devi...
# Split into 5 sentences
# Successfully processed review 60040
#
# Processing review 60041: Pretty good,Overall pretty good. Hoods keep slidin...
# Split into 5 sentences
# Successfully processed review 60041
#
# Processing review 60042: Good I mean at least it works,Solid comfortable bi...
# Split into 6 sentences
# Successfully processed review 60042
#
# Processing review 60043: Quality bike. Terrible shipping.,I only have a few...
# Split into 19 sentences
# Successfully processed review 60043
#
# Processing review 60044: ROI is Questionable,The construction is solid and ...
# Split into 14 sentences
# Successfully processed review 60044
#
# Processing review 60045: It makes strange clack sounds,It makes strange cla...
# Split into 1 sentences
# Successfully processed review 60045
#
# Processing review 60046: Solid training platform,The bike has worked well s...
# Split into 7 sentences
# Successfully processed review 60046
#
# Processing review 60047: Our new bike,We are enjoying our new bike. We were...
# Split into 2 sentences
# Successfully processed review 60047
#
# Processing review 60048: Okay but there's room for improvement,Overall I'm ...
# Split into 12 sentences
# Successfully processed review 60048
#
# Processing review 60049: Can tell it’s used but bike works,I read many revi...
# Split into 3 sentences
# Successfully processed review 60049
#
# Processing review 60050: Love using this,I would have rated this at 5* from...
# Split into 11 sentences
# Successfully processed review 60050
#
# Processing review 60051: Speedy legs,I use it at least 4x a week! My bigges...
# Split into 3 sentences
# Successfully processed review 60051
#
# Processing review 60052: Almost a 5 Star. It's Just Me.,Better than expecte...
# Split into 13 sentences
# Successfully processed review 60052
#
# Processing review 60053: Integrated Training at its best,I have enjoyed my ...
# Split into 9 sentences
# Successfully processed review 60053
#
# Processing review 60054: Reconditioned Kickr Bike,Just purchased a recondit...
# Split into 6 sentences
# Successfully processed review 60054
#
# Processing review 60055: Wahoo Kikr Bike V1,Very solid platform. Have to sa...
# Split into 14 sentences
# Successfully processed review 60055
#
# Processing review 60056: Bike trainer,It’s a good piece of equipment but th...
# Split into 2 sentences
# Successfully processed review 60056
#
# Processing review 60057: New Research Lab Bike Thoughts,Overall the bike wa...
# Split into 9 sentences
# Successfully processed review 60057
#
# Processing review 60058: FYI,Everything works great except for the blue too...
# Split into 1 sentences
# Successfully processed review 60058
#
# Processing review 60059: Awesome bike, but needs new components for taller ...
# Split into 3 sentences
# Successfully processed review 60059
#
# Processing review 60060: Shipping was incredibly slow. Bike,Shipping was in...
# Split into 6 sentences
# Successfully processed review 60060
#
# Processing review 60061: Take some time to get,Take some time to get fit ri...
# Split into 1 sentences
# Successfully processed review 60061
#
# Processing review 60062: So for its very good,,So for its very good, but I'...
# Split into 2 sentences
# Successfully processed review 60062
#
# Processing review 60063: Makes noise…can’t figure it out,Makes noise…can’t ...
# Skipping non-English review (detected: fr)
#
# Processing review 60064: So far so good. Got,So far so good. Got the bike a...
# Split into 9 sentences
# Successfully processed review 60064
#
# Processing review 60065: Love it,Built well. starting to notice a bit of fo...
# Split into 7 sentences
# Successfully processed review 60065
#
# Processing review 60066: pro's and cons.,pro is the whole experience. con i...
# Split into 3 sentences
# Successfully processed review 60066
#
# Processing review 60067: Kickr Bike Review after roughly 6 months,Overall I...
# Split into 12 sentences
# Successfully processed review 60067
#
# Processing review 60068: Great bike for Zwift that takes up less room than ...
# Split into 15 sentences
# Successfully processed review 60068
#
# Processing review 60069: Great machine, could use a few tweaks,Nice machine...
# Split into 7 sentences
# Successfully processed review 60069
#
# Processing review 60070: This is my third trainer,This is my third trainer ...
# Split into 2 sentences
# Successfully processed review 60070
#
# Processing review 60071: For those times when …,For the days when there isn...
# Split into 5 sentences
# Successfully processed review 60071
#
# Processing review 60072: The bike works great! Just,The bike works great! J...
# Split into 6 sentences
# Successfully processed review 60072
#
# Processing review 60073: Close to road bike feel but not exact.,The Kickr b...
# Split into 9 sentences
# Successfully processed review 60073
#
# Processing review 60074: Very good product Shame the,Very good product
# Sha...
# Split into 1 sentences
# Successfully processed review 60074
#
# Processing review 60075: Solid build quality and easy,Solid build quality a...
# Split into 5 sentences
# Successfully processed review 60075
#
# Processing review 60076: Pleased, but slightly unhappy,I am happy with the ...
# Split into 8 sentences
# Successfully processed review 60076
#
# Processing review 60077: Good with room for creative improvements,Great bik...
# Split into 5 sentences
# Successfully processed review 60077
#
# Processing review 60078: Almost awesome,This is a really good bike that's a...
# Split into 16 sentences
# Successfully processed review 60078
#
# Processing review 60079: Apart from having problems its,Apart from having p...
# Split into 1 sentences
# Successfully processed review 60079
#
# Processing review 60080: Good, but expensive,Good, but expensive. All the p...
# Split into 2 sentences
# Successfully processed review 60080
#
# Processing review 60081: The KIckr Bike would be,The KIckr Bike would be gr...
# Split into 2 sentences
# Successfully processed review 60081
#
# Processing review 60082: I love the bike. The,I love the bike. The handleba...
# Split into 3 sentences
# Successfully processed review 60082
#
# Processing review 60083: Not happy yet.,Seat post! It won’t stay put. Bike ...
# Split into 6 sentences
# Successfully processed review 60083
#
# Processing review 60084: So so- haven’t been excited,So so- haven’t been ex...
# Split into 1 sentences
# Successfully processed review 60084
#
# Processing review 60085: Great bike, strange noises,I had a KICKR Core year...
# Split into 7 sentences
# Successfully processed review 60085
#
# Processing review 60086: This bike has revolutionised my,This bike has revo...
# Split into 25 sentences
# Successfully processed review 60086
#
# Processing review 60087: Very good equipment. However, it,Very good equipme...
# Split into 7 sentences
# Successfully processed review 60087
#
# Processing review 60088: Good so far. Still trying,Good so far. Still tryin...
# Split into 3 sentences
# Successfully processed review 60088
#
# Processing review 60089: so far so good, I,so far so good, I really enjoy i...
# Split into 1 sentences
# Successfully processed review 60089
#
# Processing review 60090: Worth the upgrade👍,All the reviews I read are accu...
# Split into 19 sentences
# Successfully processed review 60090
#
# Processing review 60091: I love my Kickr,I am really enjoying my Kickr bike...
# Split into 12 sentences
# Successfully processed review 60091
#
# Processing review 60092: The right shifter didn't work,The right shifter di...
# Split into 4 sentences
# Successfully processed review 60092
#
# Processing review 60093: Almost as good as the real thing.,Have had a few i...
# Split into 3 sentences
# Successfully processed review 60093
#
# Processing review 60094: Great except for seatpost slip,Everything is actua...
# Split into 3 sentences
# Successfully processed review 60094
#
# Processing review 60095: It feels like the real thing!,Kickr Bike started a...
# Split into 15 sentences
# Successfully processed review 60095
#
# Processing review 60096: Kickr Review,Bike seems well built and of durable ...
# Split into 13 sentences
# Successfully processed review 60096
#
# Processing review 60097: Recent purchase,Great product, could be improved i...
# Split into 2 sentences
# Successfully processed review 60097
#
# Processing review 60098: Out the box the left,Out the box the left shifter ...
# Split into 3 sentences
# Successfully processed review 60098
#
# Processing review 60099: Awesome with Zwift, but quick release seat height ...
# Split into 4 sentences
# Successfully processed review 60099
#
# Processing review 60100: Initial Impressions,One week of use and these are ...
# Split into 21 sentences
# Successfully processed review 60100
#
# Processing review 60101: Good flexibility, easy to adjust,Good flexibility,...
# Split into 4 sentences
# Successfully processed review 60101
#
# Processing review 60102: Fabulous and worth every penny!,Absolutely love th...
# Split into 14 sentences
# Successfully processed review 60102
#
# Processing review 60103: Love the bike the one,Love the bike the one issue ...
# Split into 1 sentences
# Successfully processed review 60103
#
# Processing review 60104: very easy to setup and,very easy to setup and star...
# Split into 1 sentences
# Successfully processed review 60104
#
# Processing review 60105: Almost perfect,Almost perfect. The only thing that...
# Split into 2 sentences
# Successfully processed review 60105
#
# Processing review 60106: Nice app and bike,Excellent bike, a few glitches. ...
# Split into 4 sentences
# Successfully processed review 60106
#
# Processing review 60107: Good experience so far. The,Good experience so far...
# Split into 7 sentences
# Successfully processed review 60107
#
# Processing review 60108: Novice Indoor rider,After a lot of research I deci...
# Split into 9 sentences
# Successfully processed review 60108
#
# Processing review 60109: Good but good be improved,Works very smoothly
# Shif...
# Split into 1 sentences
# Successfully processed review 60109
#
# Processing review 60110: Feature wise and setup is,Feature wise and setup i...
# Split into 3 sentences
# Successfully processed review 60110
#
# Processing review 60111: So glad to have it!,Solid bike and really great ri...
# Split into 5 sentences
# Successfully processed review 60111
#
# Processing review 60112: Very enjoyable,Very good bit of equipment...
# Split into 1 sentences
# Successfully processed review 60112
#
# Processing review 60113: Certified reconditioned Kickr Bike,The bike works ...
# Split into 6 sentences
# Successfully processed review 60113
#
# Processing review 60114: Shifters didn’t work. Wahoo replaced,Shifters didn...
# Split into 6 sentences
# Successfully processed review 60114
#
# Processing review 60115: On paper brilliant, but not 100% on build quality....
# Split into 11 sentences
# Successfully processed review 60115
#
# Processing review 60116: Kickr bike + desk combo,The Wahoo Kickr bike is a ...
# Split into 4 sentences
# Successfully processed review 60116
#
# Processing review 60117: Brilliant,The bike is brilliant! Amazing piece of ...
# Split into 5 sentences
# Successfully processed review 60117
#
# Processing review 60118: works well,works well...
# Skipping non-English review (detected: af)
#
# Processing review 60119: Almost perfect....,Good piece of kit, easy to set ...
# Split into 5 sentences
# Successfully processed review 60119
#
# Processing review 60120: New Kickr Bike after 2 weeks of using,Fantastic bi...
# Split into 5 sentences
# Successfully processed review 60120
#
# Processing review 60121: Great bit of kit,Great bit of kit...
# Split into 1 sentences
# Successfully processed review 60121
#
# Processing review 60122: Too expensive,Good but not perfect.
# High price an...
# Split into 3 sentences
# Successfully processed review 60122
#
# Processing review 60123: Good but could be better,Intuitive and easy to use...
# Split into 8 sentences
# Successfully processed review 60123
#
# Processing review 60124: Almost there,An excellent bike, but could be impro...
# Split into 1 sentences
# Successfully processed review 60124
#
# Processing review 60125: Kickr bike,Great bike , very accurate, very quiet ...
# Split into 1 sentences
# Successfully processed review 60125
#
# Processing review 60126: Expensive but good training aid,Very expensive, a ...
# Split into 1 sentences
# Successfully processed review 60126
#
# Processing review 60127: Kickr bike,Very different feel to the kickr traine...
# Split into 2 sentences
# Successfully processed review 60127
#
# Processing review 60128: Nice Bike , Would like to buy one,Hi,
#
# I'am lookin...
# Split into 9 sentences
# Successfully processed review 60128
#
# Processing review 60129: Great but could be improved...,I have about 900 mi...
# Split into 22 sentences
# Successfully processed review 60129
#
# Processing review 60130: OK but read the comments before you buy,Very cool ...
# Split into 7 sentences
# Successfully processed review 60130
#
# Processing review 60131: Mostly good,I rate it between pretty good and pret...
# Split into 4 sentences
# Successfully processed review 60131
#
# Processing review 60132: Great bike, with to many issues out of the box,I w...
# Split into 9 sentences
# Successfully processed review 60132
#
# Processing review 60133: Great ride, once you‘ve been through the setup,Onc...
# Split into 11 sentences
# Successfully processed review 60133
#
# Processing review 60134: Not ideal,The bike arrived dirty. Not sure how muc...
# Split into 3 sentences
# Successfully processed review 60134
#
# Processing review 60135: Refurbished kickr bike,Have had a new one in Denma...
# Split into 2 sentences
# Successfully processed review 60135
#
# Processing review 60136: Purchase final,Nice bike. Expensive plus $150 deli...
# Split into 4 sentences
# Successfully processed review 60136
#
# Processing review 60137: Okay but not that satisfied.,Wahoo would better up...
# Split into 3 sentences
# Successfully processed review 60137
#
# Processing review 60138: Dissappointed,Confusing setup, impossible instruct...
# Split into 2 sentences
# Successfully processed review 60138
#
# Processing review 60139: DISAPPOINTMENT AWAITS,Very poor communication and ...
# Split into 10 sentences
# Successfully processed review 60139
#
# Processing review 60140: The bike is great but,The bike is great but I am h...
# Split into 1 sentences
# Successfully processed review 60140
#
# Processing review 60141: Handle bar stem arrived bent,,Handle bar stem arri...
# Split into 3 sentences
# Successfully processed review 60141
#
# Processing review 60142: Quality,The bolt for the saddle QR ring broke on d...
# Split into 4 sentences
# Successfully processed review 60142
#
# Processing review 60143: Dialing it in and shifting,We don't have it quite ...
# Split into 1 sentences
# Successfully processed review 60143
#
# Processing review 60144: Love it but many (small?) issues,I should start sa...
# Split into 16 sentences
# Successfully processed review 60144
#
# Processing review 60145: Poor quality quick release levers lead to seat and...
# Split into 8 sentences
# Successfully processed review 60145
#
# Processing review 60146: Nice Tech but Terrible Quality,The good:
# - Easy t...
# Split into 17 sentences
# Successfully processed review 60146
#
# Processing review 60147: Fun to use but not worth the money,Lots of feedbac...
# Split into 8 sentences
# Successfully processed review 60147
#
# Processing review 60148: It is ok, glad I can afford to be somewhat content...
# Split into 6 sentences
# Successfully processed review 60148
#
# Processing review 60149: Room for improvement,On the plus side, the build w...
# Split into 10 sentences
# Successfully processed review 60149
#
# Processing review 60150: It’s okay,I thought it would be life changing and ...
# Split into 10 sentences
# Successfully processed review 60150
#
# Processing review 60151: Bike is okay. Saddle is,Bike is okay. Saddle is be...
# Split into 16 sentences
# Successfully processed review 60151
#
# Processing review 60152: I miss sensors to measure,I miss sensors to measur...
# Split into 8 sentences
# Successfully processed review 60152
#
# Processing review 60153: Steertube cannot be fixed properly,Impossible to f...
# Split into 3 sentences
# Successfully processed review 60153
#
# Processing review 60154: Customer Support,I am still experiencing issues wi...
# Split into 3 sentences
# Successfully processed review 60154
#
# Processing review 60155: Well designed smart trainer with quality issues,I ...
# Split into 5 sentences
# Successfully processed review 60155
#
# Processing review 60156: Kickr Bike,I love the technology that the Kickr Bi...
# Split into 7 sentences
# Successfully processed review 60156
#
# Processing review 60157: Wahoo,I would like the screen in color, bigger scr...
# Split into 1 sentences
# Successfully processed review 60157
#
# Processing review 60158: Maybe 3rd bike will work!,Not the best purchase I ...
# Split into 7 sentences
# Successfully processed review 60158
#
# Processing review 60159: Good bike, beware of fitting challenges,Do not buy...
# Split into 5 sentences
# Successfully processed review 60159
#
# Processing review 60160: Despite it is advertised how,Despite it is adverti...
# Split into 1 sentences
# Successfully processed review 60160
#
# Processing review 60161: Head’s Up: Not Great,The bike we received was inco...
# Split into 4 sentences
# Successfully processed review 60161
#
# Processing review 60162: Gears not calibrated,Very bad experience so far. T...
# Split into 3 sentences
# Successfully processed review 60162
#
# Processing review 60163: DOA,My bike was dead on arrival. I had to send it ...
# Split into 6 sentences
# Successfully processed review 60163
#
# Processing review 60164: 1st reconditioned bike i received,1st reconditione...
# Split into 1 sentences
# Successfully processed review 60164
#
# Processing review 60165: The app froze and I,The app froze and I had to del...
# Split into 1 sentences
# Successfully processed review 60165
#
# Processing review 60166: Love it,To get in shape...
# Skipping non-English review (detected: nl)
#
# Processing review 60167: Impression is used, not refurbished.,Before I went...
# Split into 10 sentences
# Successfully processed review 60167
#
# Processing review 60168: Bad quality for the money,My father and I both bou...
# Split into 4 sentences
# Successfully processed review 60168
#
# Processing review 60169: Frustrating order process,Really enjoying the bike...
# Split into 13 sentences
# Successfully processed review 60169
#
# Processing review 60170: Terrible Experience,I ordered the bike on 28 Nov 2...
# Split into 8 sentences
# Successfully processed review 60170
#
# Processing review 60171: I bought this product and,I bought this product an...
# Split into 4 sentences
# Successfully processed review 60171
#
# Processing review 60172: KICKR Bike,When I received my bike and finished th...
# Split into 10 sentences
# Successfully processed review 60172
#
# Processing review 60173: So much to be pleased about but one major flaw,The...
# Split into 5 sentences
# Successfully processed review 60173
#
# Processing review 60174: Not so “certified”,Bike came defective straight ou...
# Split into 2 sentences
# Successfully processed review 60174
#
# Processing review 60175: I received this a week,I received this a week ago....
# Split into 8 sentences
# Successfully processed review 60175
#
# Processing review 60176: So so,Lots of nice features, but a few are poorly ...
# Split into 4 sentences
# Successfully processed review 60176
#
# Processing review 60177: Buy new not “reconditioned”,Arrived not working pr...
# Split into 6 sentences
# Successfully processed review 60177
#
# Processing review 60178: Love the bike but unfortunately,Love the bike but ...
# Split into 4 sentences
# Successfully processed review 60178
#
# Processing review 60179: Not too sure if this es sa smart buy,Reconditioned...
# Split into 9 sentences
# Successfully processed review 60179
#
# Processing review 60180: .,....
# Error detecting language: No features in text.
# Skipping non-English review (detected: unknown)
#
# Processing review 60181: Clicking noises,The bike makes annoying clicking s...
# Split into 2 sentences
# Successfully processed review 60181
#
# Processing review 60182: Too tall at 6'3",The product is advertised as work...
# Split into 3 sentences
# Successfully processed review 60182
#
# Processing review 60183: I luv my bike,Luv it...
# Skipping non-English review (detected: et)
#
# Processing review 60184: Wait for version 2,I so want this to be the ultima...
# Split into 12 sentences
# Successfully processed review 60184
#
# Processing review 60185: So wanted to like it, sadly returning.,Very well m...
# Split into 10 sentences
# Successfully processed review 60185
#
# Processing review 60186: Not happy at this point,It's surprising that Wahoo...
# Split into 2 sentences
# Successfully processed review 60186
#
# Processing review 60187: Not worth the price,This is my third dedicated ind...
# Split into 15 sentences
# Successfully processed review 60187
#
# Processing review 60188: Kinks need to be worked out,Using the Trainer Road...
# Split into 5 sentences
# Successfully processed review 60188
#
# Processing review 60189: Overpriced, doesn't outperform cheaper trainers,I'...
# Split into 3 sentences
# Successfully processed review 60189
#
# Processing review 60190: Unreliable,On my second one after going through th...
# Split into 3 sentences
# Successfully processed review 60190
#
# Processing review 60191: Waste of Money,Resistance on ERG mode is all over ...
# Split into 6 sentences
# Successfully processed review 60191
#
# Processing review 60192: Potentially great, currently disappointing…,When i...
# Split into 17 sentences
# Successfully processed review 60192
#
# Processing review 60193: SENT WRONG BIKE,You sent me the wrong bike. I orde...
# Split into 2 sentences
# Successfully processed review 60193
#
# Processing review 60194: Broke out of box , still doesn’t work.,Didn’t work...
# Split into 6 sentences
# Successfully processed review 60194
#
# Processing review 60195: Annoying clicking when pedaling coming,Annoying cl...
# Split into 2 sentences
# Successfully processed review 60195
#
# Processing review 60196: Refurb bike obviously not tested before shipping.,...
# Split into 7 sentences
# Successfully processed review 60196
#
# Processing review 60197: Wasting my time,Struggling to see how Wahoo can de...
# Split into 6 sentences
# Successfully processed review 60197
#
# Processing review 60198: Disappointed,Out of the box new, the Kickr smart b...
# Split into 5 sentences
# Successfully processed review 60198
#
# Processing review 60199: No happy with this purchase,I bought the smart bik...
# Split into 10 sentences
# Successfully processed review 60199
#
# Processing review 60200: Certified Reconditioned is a Joke!,I will NEVER ge...
# Split into 15 sentences
# Successfully processed review 60200
#
# Processing review 60201: I bought the certified bike,I bought the certified...
# Split into 1 sentences
# Successfully processed review 60201
#
# Processing review 60202: Reconditioned? No QC!,So disappointed to receive t...
# Split into 5 sentences
# Successfully processed review 60202
#
# Processing review 60203: 3 months, still no bike,I can't review the actual ...
# Split into 4 sentences
# Successfully processed review 60203
#
# Processing review 60204: Wouldn’t know…still don’t have it,,Wouldn’t know…s...
# Split into 1 sentences
# Successfully processed review 60204
#
# Processing review 60205: Think twice!!!,Ordered before Christmas. First bik...
# Split into 8 sentences
# Successfully processed review 60205
#
# Processing review 60206: Not reconditioned,The one I received was rusted al...
# Split into 3 sentences
# Successfully processed review 60206
#
# Processing review 60207: Ordered 5 weeks ago, still not delivered,I ordered...
# Split into 3 sentences
# Successfully processed review 60207
#
# Processing review 60208: Problems,Almost a month after ordering. No bike, n...
# Split into 2 sentences
# Successfully processed review 60208
#
# Processing review 60209: After ordering on Black Friday,,After ordering on ...
# Split into 2 sentences
# Successfully processed review 60209
#
# Processing review 60210: 3 Reasons Not To Buy,Very disappointed with the Ki...
# Split into 7 sentences
# Successfully processed review 60210
#
# Processing review 60211: Delivery service is seriously struggling,Still hav...
# Split into 2 sentences
# Successfully processed review 60211
#
# Processing review 60212: I’ve yet to receive my,I’ve yet to receive my bike...
# Split into 3 sentences
# Successfully processed review 60212
#
# Processing review 60213: Definitely recommend!,I got my IC SE bike a few we...
# Split into 7 sentences
# Successfully processed review 60213
#
# Processing review 60214: Horrific shipping experience,Bike hasn’t been deli...
# Split into 7 sentences
# Successfully processed review 60214
#
# Processing review 60215: Wishing for Better Customer Service,I purchased th...
# Split into 7 sentences
# Successfully processed review 60215
#
# Processing review 60216: Defective product,I have had the kickr bike for ab...
# Split into 1 sentences
# Successfully processed review 60216
#
# Processing review 60217: Beware of “Certified Reconditioned”,Hard to write ...
# Split into 7 sentences
# Successfully processed review 60217
#
# Processing review 60218: Very disappointed,After considering buying a new v...
# Split into 9 sentences
# Successfully processed review 60218
#
# Processing review 60219: If you order the Bike, good luck with it actually ...
# Split into 9 sentences
# Successfully processed review 60219
#
# Processing review 60220: Likely good product, TERRIBLE delivery/execution.,...
# Split into 6 sentences
# Successfully processed review 60220
#
# Processing review 60221: Customer service severely lacking.,I ordered my bi...
# Split into 13 sentences
# Successfully processed review 60221
#
# Processing review 60222: Totally disappointed and frustrated with the bike ...
# Split into 28 sentences
# Successfully processed review 60222
#
# Processing review 60223: Terrible experience.,After easily setting up the k...
# Split into 10 sentences
# Successfully processed review 60223
#
# Processing review 60224: Arrived broken…and now a giant paper weight,I orde...
# Split into 18 sentences
# Successfully processed review 60224
#
# Processing review 60225: I would buy this again,I am really inpressed with ...
# Split into 1 sentences
# Successfully processed review 60225
#
# Processing review 60226: Great when it works, but hasn't had a working one ...
# Split into 5 sentences
# Successfully processed review 60226
#
# Processing review 60227: HORRENDOUS CUSTOMER SERVICES,HORRENDOUS CUSTOMER S...
# Skipping non-English review (detected: de)
#
# Processing review 60228: still waiting,still haven t recived my product. de...
# Split into 4 sentences
# Successfully processed review 60228
#
# Processing review 60229: Bike came damaged; paid $4k,Bike came damaged; pai...
# Split into 2 sentences
# Successfully processed review 60229
#
# Processing review 60230: It was broken when received. There was no way they...
# Split into 12 sentences
# Successfully processed review 60230
#
# Processing review 60231: The COVIT excuse,I ordered my trainer over 4 month...
# Split into 10 sentences
# Successfully processed review 60231
#
# Processing review 60232: Didn't work out of the box,When I took the bike ou...
# Split into 14 sentences
# Successfully processed review 60232
#
# Processing review 60233: Great Value,Ive had this thing for about a month o...
# Split into 8 sentences
# Successfully processed review 60233
#
# Processing review 60234: So Glad I Purchased This Bike!,The Bowflex bike me...
# Split into 6 sentences
# Successfully processed review 60234
#
# Processing review 60235: Excellent Bike,Go to gym 4-5 days a week , this bi...
# Split into 1 sentences
# Successfully processed review 60235
#
# Processing review 60236: This bike is everything you need!  Superior equipm...
# Split into 9 sentences
# Successfully processed review 60236
#
# Processing review 60237: Best fitness purchase,I use it every morning befor...
# Split into 3 sentences
# Successfully processed review 60237
#
# Processing review 60238: This bike is great!,This bike is great! I upgraded...
# Split into 8 sentences
# Successfully processed review 60238
#
# Processing review 60239: A really well built bike. I would definitely recom...
# Split into 4 sentences
# Successfully processed review 60239
#
# Processing review 60240: Everything you ever wanted in a fitness cycle,I pu...
# Split into 6 sentences
# Successfully processed review 60240
#
# Processing review 60241: Great Smooth Ride, Quality Resistance, Awesome Wor...
# Split into 5 sentences
# Successfully processed review 60241
#
# Processing review 60242: I absolutely love this bike,I love this bike. It's...
# Split into 2 sentences
# Successfully processed review 60242
#
# Processing review 60243: Buy a Bowflex!,My wife and I began our exercise bi...
# Split into 5 sentences
# Successfully processed review 60243
#
# Processing review 60244: Has made me love cycling,I have always preferred a...
# Split into 7 sentences
# Successfully processed review 60244
#
# Processing review 60245: Great bike !,Bought this to use for the winter tim...
# Split into 8 sentences
# Successfully processed review 60245
#
# Processing review 60246: Not as sturdy as claimed and resistance is not cot...
# Split into 6 sentences
# Successfully processed review 60246
#
# Processing review 60247: Great spin bike with good features,I haven't had i...
# Split into 9 sentences
# Successfully processed review 60247
#
# Processing review 60248: Generally good,The good: the console is excellent ...
# Split into 30 sentences
# Successfully processed review 60248
#
# Processing review 60249: Definitely,  very happy with this bike.,I've had t...
# Split into 8 sentences
# Successfully processed review 60249
#
# Processing review 60250: Smooth ride,#sweepstakes...
# Skipping non-English review (detected: af)
#
# Processing review 60251: Smooth Ride,Jump on for cardio.  I love the spin b...
# Split into 6 sentences
# Successfully processed review 60251
#
# Processing review 60252: Highly recommended,Overall, a well-constructed exe...
# Split into 3 sentences
# Successfully processed review 60252
#
# Processing review 60253: Great bike. Abysmal seat.,Love how simple it was t...
# Split into 7 sentences
# Successfully processed review 60253
#
# Processing review 60254: I would buy this product again. Solid and well bui...
# Split into 4 sentences
# Successfully processed review 60254
#
# Processing review 60255: I would purchase this product again,I like the bik...
# Split into 1 sentences
# Successfully processed review 60255
#
# Processing review 60256: Love it,Use it about 30 minutes every day.
# #sweep...
# Split into 2 sentences
# Successfully processed review 60256
#
# Processing review 60257: Very well built, great assembly instructions,Looke...
# Split into 4 sentences
# Successfully processed review 60257
#
# Processing review 60258: Silent pedaler,Highly recommended form of low-impa...
# Split into 1 sentences
# Successfully processed review 60258
#
# Processing review 60259: Good bike for the price,Pretty good bike for the p...
# Split into 7 sentences
# Successfully processed review 60259
#
# Processing review 60260: Love this bike!,This is an amazing bike.  Super qu...
# Split into 8 sentences
# Successfully processed review 60260
#
# Processing review 60261: Spinning obsessed! #sweepstakes,So glad I purchase...
# Split into 4 sentences
# Successfully processed review 60261
#
# Processing review 60262: The Bluetooth connection is difficult to connect.,...
# Split into 3 sentences
# Successfully processed review 60262
#
# Processing review 60263: Easy to setup, quiet, nice product,The bike was ea...
# Split into 6 sentences
# Successfully processed review 60263
#
# Processing review 60264: A real nice indoor bike.,The bike has exceeded my ...
# Split into 5 sentences
# Successfully processed review 60264
#
# Processing review 60265: Absolutely fantastic. Would buy again. Highly reco...
# Split into 6 sentences
# Successfully processed review 60265
#
# Processing review 60266: Very quiet and quick set up,I was looking for a sp...
# Split into 4 sentences
# Successfully processed review 60266
#
# Processing review 60267: Solid Bike, uncomfortable seat,Very easy to set up...
# Split into 3 sentences
# Successfully processed review 60267
#
# Processing review 60268: Smooth ride, great price,I really like this bike b...
# Split into 2 sentences
# Successfully processed review 60268
#
# Processing review 60269: Exactly what I was looking for,I use this with the...
# Split into 3 sentences
# Successfully processed review 60269
#
# Processing review 60270: I want to love it but I cannot use it,I am awaitin...
# Split into 4 sentences
# Successfully processed review 60270
#
# Processing review 60271: Love the machine.!!!,Use the machine daily, to  ma...
# Split into 2 sentences
# Successfully processed review 60271
#
# Processing review 60272: Nice bike for at home,I take cycle class once a we...
# Split into 2 sentences
# Successfully processed review 60272
#
# Processing review 60273: Lovin' it!,I've had the IC Bike SE for almost 3 we...
# Split into 16 sentences
# Successfully processed review 60273
#
# Processing review 60274: Nice biking experience,I am on a every other day s...
# Split into 5 sentences
# Successfully processed review 60274
#
# Processing review 60275: Great bike that meets my needs!,This bike is aesth...
# Split into 8 sentences
# Successfully processed review 60275
#
# Processing review 60276: not sure yet,Still can't get it to connect to my h...
# Split into 2 sentences
# Successfully processed review 60276
#
# Processing review 60277: Love this bike!,Better workout than expected! Grea...
# Split into 4 sentences
# Successfully processed review 60277
#
# Processing review 60278: Beginner and Loving It!,I'm getting old, 64 almost...
# Split into 17 sentences
# Successfully processed review 60278
#
# Processing review 60279: Great buy!!,It's perfect to use at the end of the ...
# Split into 2 sentences
# Successfully processed review 60279
#
# Processing review 60280: Sturdy, Quiet, and Sleek,I needed a bike that woul...
# Split into 4 sentences
# Successfully processed review 60280
#
# Processing review 60281: Best bike I've used,I use this every day. Works aw...
# Split into 3 sentences
# Successfully processed review 60281
#
# Processing review 60282: Great bike/workout!,Several family members use thi...
# Split into 9 sentences
# Successfully processed review 60282
#
# Processing review 60283: I would recommend this bike to all friends and fam...
# Split into 1 sentences
# Successfully processed review 60283
#
# Processing review 60284: This product is perfect!,The BowFlex IC Bike SE is...
# Split into 3 sentences
# Successfully processed review 60284
#
# Processing review 60285: Half the price of a Peloton,I wish it could share ...
# Split into 1 sentences
# Successfully processed review 60285
#
# Processing review 60286: Great Workout Bike,This bike is a great beginners ...
# Split into 4 sentences
# Successfully processed review 60286
#
# Processing review 60287: great product and would recommend to others!,this ...
# Split into 5 sentences
# Successfully processed review 60287
#
# Processing review 60288: Awesome bike!,This is one sturdy bike! Its so easy...
# Split into 8 sentences
# Successfully processed review 60288
#
# Processing review 60289: This is great!,Bowflex gave me this BowFlex IC Bik...
# Split into 7 sentences
# Successfully processed review 60289
#
# Processing review 60290: Great bike but connectivity issues,Bowflex kindly ...
# Split into 8 sentences
# Successfully processed review 60290
#
# Processing review 60291: Bowflex IC Bike SE,Full disclosure: I received thi...
# Split into 26 sentences
# Successfully processed review 60291
#
# Processing review 60292: Exceeded all expectations,This is an amazing produ...
# Split into 3 sentences
# Successfully processed review 60292
#
# ...
# Split into 5 sentences
# Successfully processed review 77816
#
# Processing review 77817: I didn't do a deep enough dive on this product so ...
# Split into 5 sentences
# Successfully processed review 77817
#
# Processing review 77818: I was excited about this treadmill since it doesn’...
# Split into 5 sentences
# Successfully processed review 77818
#
# Processing review 77819: Omg I just hate this treadmill manual it suck, whe...
# Split into 2 sentences
# Successfully processed review 77819
#
# Processing review 77820: This item was not very hard to assemble. However, ...
# Split into 7 sentences
# Successfully processed review 77820
#
# Processing review 77821: This is a great way to get more steps in when the ...
# Split into 1 sentences
# Successfully processed review 77821
#
# Processing review 77822: First, it’s rickety. Second it’s like walking on a...
# Split into 10 sentences
# Successfully processed review 77822
#
# Processing review 77823: I was disappointed when I got this. The assembly w...
# Split into 4 sentences
# Successfully processed review 77823
#
# Processing review 77824: I personally would return if it wasn't for the fac...
# Split into 4 sentences
# Successfully processed review 77824
#
# Processing review 77825: I bought this thinking it would at least be smooth...
# Split into 12 sentences
# Successfully processed review 77825
#
# Processing review 77826: This thing is absolutely dangerous. The angle of t...
# Split into 6 sentences
# Successfully processed review 77826
#
# Processing review 77827: This product can’t be used. I am beyond disappoint...
# Split into 12 sentences
# Successfully processed review 77827
#
# Processing review 77828: I bought this to get some extra steps in. The firs...
# Split into 9 sentences
# Successfully processed review 77828
#
# Processing review 77829: The photo that is advertised for this product is c...
# Split into 7 sentences
# Successfully processed review 77829
#
# Processing review 77830: So disappointed! Must hold onto the handlebars the...
# Split into 3 sentences
# Successfully processed review 77830
#
# Processing review 77831: This treadmill is difficult to manage. Because of ...
# Split into 6 sentences
# Successfully processed review 77831
#
# Processing review 77832: You have to keep moving and you really cannot go a...
# Split into 5 sentences
# Successfully processed review 77832
#
# Processing review 77833: What I liked:The priceThe sizeThe fact that it is ...
# Split into 6 sentences
# Successfully processed review 77833
#
# Processing review 77834: I honestly hate this treadmill. It’s been nothing ...
# Split into 10 sentences
# Successfully processed review 77834
#
# Processing review 77835: Bought the treadmill for reverse walking to train ...
# Split into 4 sentences
# Successfully processed review 77835
#
# Processing review 77836: Worse purchase I ever made on Amazon!  I was excit...
# Split into 6 sentences
# Successfully processed review 77836
#
# Processing review 77837: Do not buy this! I opened the box and there were n...
# Split into 8 sentences
# Successfully processed review 77837
#
# Processing review 77838: this product was the biggest waste of space and mo...
# Split into 3 sentences
# Successfully processed review 77838
#
# Processing review 77839: I just had a total hip replacement and with the we...
# Split into 4 sentences
# Successfully processed review 77839
#
# Processing review 77840: Sure, this treadmill is very inexpensive, but hone...
# Split into 8 sentences
# Successfully processed review 77840
#
# Processing review 77841: I hate this machine. I could get over the narrow b...
# Split into 6 sentences
# Successfully processed review 77841
#
# Processing review 77842: I brought this treadmill back in October 2019.  I ...
# Split into 7 sentences
# Successfully processed review 77842
#
# Processing review 77843: Sadly, no matter how much I tighten the belt it's ...
# Split into 7 sentences
# Successfully processed review 77843
#
# Processing review 77844: I like the compact size. Doesn't take up alot of r...
# Split into 6 sentences
# Successfully processed review 77844
#
# Processing review 77845: Goes to fast even when I try to slow down, the bel...
# Split into 1 sentences
# Successfully processed review 77845
#
# Processing review 77846: I have had this treadmill almost one year, for the...
# Split into 7 sentences
# Successfully processed review 77846
#
# Processing review 77847: I got this product after releasing from hospital f...
# Split into 4 sentences
# Successfully processed review 77847
#
# Processing review 77848: This is NOT ELECTRONIC! Warning!!!  The belt only ...
# Split into 4 sentences
# Successfully processed review 77848
#
# Processing review 77850: I wish I had read the one star reviews. I’m 5’10 a...
# Split into 6 sentences
# Successfully processed review 77850
#
# Processing review 77851: Don’t waste your money on this treadmill. This thi...
# Split into 10 sentences
# Successfully processed review 77851
#
# Processing review 77852: You do have to put together the treadmill which ta...
# Split into 5 sentences
# Successfully processed review 77852
#
# Processing review 77853: I had an issue with the "computer " which was not ...
# Split into 3 sentences
# Successfully processed review 77853
#
# Processing review 77854: This is a dangerous piece of equipment!  There is ...
# Split into 7 sentences
# Successfully processed review 77854
#
# Processing review 77855: This product isn't what I assumed it would be. Thi...
# Split into 2 sentences
# Successfully processed review 77855
#
# Processing review 77856: THIS IS OKAY IF YOU ARE YOUNG AND KNOW HOW TO PUT ...
# Split into 6 sentences
# Successfully processed review 77856
#
# Processing review 77857: As others have noted, the conveyor moves very fast...
# Split into 3 sentences
# Successfully processed review 77857
#
# Processing review 77858: Treadmill not manageable for slow senior pace!...
# Split into 1 sentences
# Successfully processed review 77858
#
# Processing review 77859: Belt has no tension…very slippery. Hold on or you ...
# Split into 6 sentences
# Successfully processed review 77859
#
# Processing review 77860: This treadmill was a complete waste of time and mo...
# Split into 9 sentences
# Successfully processed review 77860
#
# Processing review 77861: I purchased this treadmill in October of 2021.  Ba...
# Split into 7 sentences
# Successfully processed review 77861
#
# Processing review 77862: Listen to the other reviews that state the treadmi...
# Split into 5 sentences
# Successfully processed review 77862
#
# Processing review 77863: This is a manual walker that you power, the descri...
# Split into 3 sentences
# Successfully processed review 77863
#
# Processing review 77864: A lot less smooth to run on overtime, even after a...
# Split into 7 sentences
# Successfully processed review 77864
#
# Processing review 77865: Hated it. Returned it.I knew what I was getting in...
# Split into 12 sentences
# Successfully processed review 77865
#
# Processing review 77866: Didn't like this at all! I wanted something foldab...
# Split into 8 sentences
# Successfully processed review 77866
#
# Processing review 77867: I tried this treadmill and it almost threw my back...
# Split into 5 sentences
# Successfully processed review 77867
#
# Processing review 77868: This is a nice little machine to keep in my home o...
# Split into 7 sentences
# Successfully processed review 77868
#
# Processing review 77869: A couple months ago the screen on my treadmill com...
# Split into 3 sentences
# Successfully processed review 77869
#
# Processing review 77870: DO NOT BUY!!! A waste of $200. I was actually exci...
# Split into 6 sentences
# Successfully processed review 77870
#
# Processing review 77871: I bought this treadmill to help my Mom get more st...
# Split into 5 sentences
# Successfully processed review 77871
#
# Processing review 77872: the hydraulic tube assembly which comes attached t...
# Split into 1 sentences
# Successfully processed review 77872
#
# Processing review 77873: There is no way to control thr speed on this. It u...
# Split into 5 sentences
# Successfully processed review 77873
#
# Processing review 77874: Disliked the poor construction and the hard job of...
# Split into 1 sentences
# Successfully processed review 77874
#
# Processing review 77875: Definitely got what i paid for great for small spa...
# Split into 1 sentences
# Successfully processed review 77875
#
# Processing review 77876: This was clearly a return item, with the box beat ...
# Split into 6 sentences
# Successfully processed review 77876
#
# Processing review 77878: The treadmill its self, is sturdy and doesn't wobb...
# Split into 5 sentences
# Successfully processed review 77878
#
# Processing review 77879: It is not adjustable so is always at a 6 inch incl...
# Split into 3 sentences
# Successfully processed review 77879
#
# Processing review 77880: Very easy to move assemble but when you start runn...
# Split into 1 sentences
# Successfully processed review 77880
#
# Processing review 77881: The reviews and pictures make this look like a per...
# Split into 6 sentences
# Successfully processed review 77881
#
# Processing review 77882: I really wanted to like this treadmill but the bel...
# Split into 5 sentences
# Successfully processed review 77882
#
# Processing review 77884: Purchased this because I am a fan of Sunny Health ...
# Split into 7 sentences
# Successfully processed review 77884
#
# Processing review 77885: Even after tightening, the belt is so loose that y...
# Split into 2 sentences
# Successfully processed review 77885
#
# Processing review 77886: Why are there so many high reviews? This is a pret...
# Split into 5 sentences
# Successfully processed review 77886
#
# Processing review 77887: Was trying to find a good affordable treadmill for...
# Split into 5 sentences
# Successfully processed review 77887
#
# Processing review 77888: The belt keeps sliding left or right after a few m...
# Split into 6 sentences
# Successfully processed review 77888
#
# Processing review 77889: I used to live in a sunny, warm climate and ran 1-...
# Split into 32 sentences
# Successfully processed review 77889
#
# Processing review 77890: I walk every weekday morning at 5am for 2 hours. I...
# Split into 30 sentences
# Successfully processed review 77890
#
# Processing review 77891: I wouldn’t recommend this manual treadmill. I was ...
# Split into 8 sentences
# Successfully processed review 77891
#
# Processing review 77892: Before you purchase this treadmill you need to be ...
# Split into 9 sentences
# Successfully processed review 77892
#
# Processing review 77893: Don't like the fact that the incline is not adjust...
# Split into 2 sentences
# Successfully processed review 77893
#
# Processing review 77894: If you are thinking of buying this for backwards w...
# Split into 12 sentences
# Successfully processed review 77894
#
# Processing review 77895: Like walking up hill. You can't adjust the board....
# Split into 2 sentences
# Successfully processed review 77895
#
# Processing review 77896: The folding was easy enough its a bit heavy though...
# Split into 4 sentences
# Successfully processed review 77896
#
# Processing review 77897: I bought this for walking on days when the weather...
# Split into 7 sentences
# Successfully processed review 77897
#
# Processing review 77898: Save your money and get a treadmill that plugs int...
# Split into 8 sentences
# Successfully processed review 77898
#
# Processing review 77899: The incline was too great I got on it and had to s...
# Split into 10 sentences
# Successfully processed review 77899
#
# Processing review 77900: I got mine a few days ago, but I’m having to lubri...
# Split into 4 sentences
# Successfully processed review 77900
#
# Processing review 77901: I like it's sturdiness, ease of use, and compact d...
# Split into 2 sentences
# Successfully processed review 77901
#
# Processing review 77902: Today was my first use, I'll be using it 5 days a ...
# Split into 11 sentences
# Successfully processed review 77902
#
# Processing review 77903: I purchased this to be able to work using my lapto...
# Split into 7 sentences
# Successfully processed review 77903
#
# Processing review 77904: The product was well packaged and had great direct...
# Split into 7 sentences
# Successfully processed review 77904
#
# Processing review 77905: I should have listened to the other reviews, the t...
# Split into 7 sentences
# Successfully processed review 77905
#
# Processing review 77906: I 100% regret buying this treadmill. Lots of the r...
# Split into 14 sentences
# Successfully processed review 77906
#
# Processing review 77907: Could not control speed. Side were not completely ...
# Split into 8 sentences
# Successfully processed review 77907
#
# Processing review 77908: the unit will not lay flat...must walk toward fron...
# Split into 3 sentences
# Successfully processed review 77908
#
# Processing review 77909: I should have read the negative reviews before thi...
# Split into 13 sentences
# Successfully processed review 77909
#
# Processing review 77910: I am just starting out and need to start slow.  Bu...
# Split into 4 sentences
# Successfully processed review 77910
#
# Processing review 77912: Well it is convenient to have but when you get on ...
# Split into 2 sentences
# Successfully processed review 77912
#
# Processing review 77913: I have been an Amazon customer for years.  I LOVE ...
# Split into 12 sentences
# Successfully processed review 77913
#
# Processing review 77914: Wanted a simple treadmill to use while watching mo...
# Split into 7 sentences
# Successfully processed review 77914
#
# Processing review 77915: I saw all the reviews from GMA and  thought I woul...
# Split into 6 sentences
# Successfully processed review 77915
#
# Processing review 77916: Good idea, terrible design. In order to keep the b...
# Split into 3 sentences
# Successfully processed review 77916
#
# Processing review 77917: Packing was good, and the item was nice and safely...
# Split into 4 sentences
# Successfully processed review 77917
#
# Processing review 77918: The slant from the front to the back of the track ...
# Split into 2 sentences
# Successfully processed review 77918
#
# Processing review 77919: Product looks nice, simple to assemble; however, t...
# Split into 6 sentences
# Successfully processed review 77919
#
# Processing review 77920: It is a smaller treadmill but the size is not nece...
# Split into 8 sentences
# Successfully processed review 77920
#
# Processing review 77921: Because of the incline, you HAVE to hold onto the ...
# Split into 3 sentences
# Successfully processed review 77921
#
# Processing review 77922: No está tan mal para usar...
# Skipping non-English review (detected: es)
#
# Processing review 77923: This was easy to assemble. However, once assembled...
# Split into 5 sentences
# Successfully processed review 77923
#
# Processing review 77924: Received the product in a timely manner.  The prob...
# Split into 12 sentences
# Successfully processed review 77924
#
# Processing review 77925: I had to revise my review. The positive is- it's s...
# Split into 8 sentences
# Successfully processed review 77925
#
# Processing review 77926: The product itself is high quality but the running...
# Split into 2 sentences
# Successfully processed review 77926
#
# Processing review 77927: I was very disappointed especially after how easy ...
# Split into 5 sentences
# Successfully processed review 77927
#
# Processing review 77928: Powered treadmills can be incredibly heavy to move...
# Split into 23 sentences
# Successfully processed review 77928
#
# Processing review 77929: a reduction in incline by putting some pegs under ...
# Split into 1 sentences
# Successfully processed review 77929
#
# Processing review 77930: Conveyer Belt absolutely will not stay centrally s...
# Split into 4 sentences
# Successfully processed review 77930
#
# Processing review 77931: Initially when I bought this it was great, 5 star ...
# Split into 3 sentences
# Successfully processed review 77931
#
# Processing review 77932: I didn’t realize the elevation is permanent....
# Split into 1 sentences
# Successfully processed review 77932
#
# Processing review 77933: This is not a treadmill you can easily run on, as ...
# Split into 4 sentences
# Successfully processed review 77933
#
# Processing review 77934: To move on the treadmill, you need to hold the bar...
# Split into 3 sentences
# Successfully processed review 77934
#
# Processing review 77935: I have to hold on for dear life when walking at a ...
# Split into 4 sentences
